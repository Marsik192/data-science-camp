# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.datasets import load_breast_cancer

# %%
cancer = load_breast_cancer()
cancer.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
df = pd.DataFrame(cancer['data'], columns = cancer['feature_names'])

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df)
# Out:
# StandardScaler()

# %%
scaled_data = scaler.transform(df)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(scaled_data)
s_pca = pca.transform(scaled_data)
scaled_data.shape
# Out:
# (569, 30)

# %%
s_pca.shape
# Out:
# (569, 2)

# %%
plt.scatter(s_pca[:,0], s_pca[:,1], c = cancer['target'])
plt.title('PCA(2 components for breast cancer dataset)')
plt.xlabel('First princible component')
plt.ylabel('Second princible component')
# Out:
# Text(0, 0.5, 'Second princible component')
